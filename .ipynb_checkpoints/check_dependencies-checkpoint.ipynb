# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import subprocess
import os
import pandas_gbq as pgbq

# %%
import google.auth
from google.auth import compute_engine
from google.cloud import bigquery

#creating the BQ client. This will ask you to log in the first time.

project_id = 'data-engineering-prod'
client = bigquery.Client(project=project_id)
client.list_datasets()

# %%
#list of datasets in 'data-engineering-prod'
datasets = [dataset.dataset_id for dataset in client.list_datasets() if not dataset.dataset_id.startswith('u_')]
print(len(datasets))
datasets
# Out:
# 237
# ['CRM',
#  'CRM_internal',
#  'alignment_orion',
#  'alignment_orion_secure',
#  'auto_capture',
#  'auto_capture_v2',
#  'auto_capture_v2_secure',
#  'bigquery_reports',
#  'cs_agent_scorecard_secure',
#  'custom_crm_secure',
#  'custom_customer_services_secure',
#  'custom_energy_ops_process_development',
#  'custom_insight',
#  'custom_ops_reporting',
#  'custom_ops_reporting_secure',
#  'custom_regulatory',
#  'data_catalogue',
#  'deltaforce_audit',
#  'deltaforce_data_migration_temp',
#  'energy_platform_secure',
#  'exception_monitoring',
#  'information',
#  'landing_acquisitions',
#  'landing_acquisitions_secure',
#  'landing_andromeda',
#  'landing_andromeda_secure',
#  'landing_apollo_cx',
#  'landing_apollo_cx_secure',
#  'landing_apollo_opex',
#  'landing_apollo_opex_secure',
#  'landing_auto_capture_v2_secure',
#  'landing_bast',
#  'landing_bast_secure',
#  'landing_bc_ovo_applications',
#  'landing_bc_ovo_applications_secure',
#  'landing_billing_correspondence',
#  'landing_billing_correspondence_secure',
#  'landing_bit',
#  'landing_bit_secure',
#  'landing_boost',
#  'landing_boost_secure',
#  'landing_brand_nps_secure',
#  'landing_bws',
#  'landing_bws_secure',
#  'landing_carbon_zero',
#  'landing_carbon_zero_secure',
#  'landing_cepheus',
#  'landing_cepheus_secure',
#  'landing_comms',
#  'landing_comms_secure',
#  'landing_crm',
#  'landing_crm_secure',
#  'landing_energyhelpline',
#  'landing_experian',
#  'landing_fieldservicestech',
#  'landing_fieldservicestech_secure',
#  'landing_flows',
#  'landing_flows_secure',
#  'landing_gen_preprod_secure',
#  'landing_gen_prod_secure',
#  'landing_homemoves',
#  'landing_homemoves_secure',
#  'landing_i3_ic_2015_prd',
#  'landing_i3_ic_2015_prd_secure',
#  'landing_identity',
#  'landing_identity_secure',
#  'landing_iht',
#  'landing_jaws',
#  'landing_jaws_secure',
#  'landing_mixpanel',
#  'landing_mixpanel_secure',
#  'landing_oot',
#  'landing_oot_secure',
#  'landing_orex',
#  'landing_orex_secure',
#  'landing_orion',
#  'landing_orion_migration',
#  'landing_orion_migration_secure',
#  'landing_orion_onboarding',
#  'landing_orion_onboarding_secure',
#  'landing_orion_secure',
#  'landing_ovo_france_identity',
#  'landing_ovo_france_identity_secure',
#  'landing_pace',
#  'landing_pace_secure',
#  'landing_payments',
#  'landing_payments_secure',
#  'landing_priority_service_register',
#  'landing_priority_service_register_secure',
#  'landing_propositions',
#  'landing_propositions_secure',
#  'landing_rise',
#  'landing_rise_qualtrics',
#  'landing_rise_qualtrics_secure',
#  'landing_rise_secure',
#  'landing_smart_device_store',
#  'landing_smart_device_store_secure',
#  'landing_smart_meter_booking',
#  'landing_smart_meter_booking_secure',
#  'landing_smint',
#  'landing_smint_secure',
#  'landing_sre',
#  'landing_sre_secure',
#  'landing_storage_gen',
#  'landing_storage_gen_secure',
#  'landing_utiliserve',
#  'logs_bigquery',
#  'logs_kubernetes_v2',
#  'mis_manual_exports',
#  'orion_eligibility',
#  'product_andromeda_secure',
#  'product_bast_secure',
#  'product_brand_nps',
#  'product_corgi',
#  'product_crm',
#  'product_crm_secure',
#  'product_digital_support_experience_secure',
#  'product_energyhelpline',
#  'product_identity_secure',
#  'product_orion',
#  'product_orion_secure',
#  'product_ovo_mobile_app',
#  'product_payments',
#  'product_payments_secure',
#  'product_rise_qualtrics',
#  'product_rise_qualtrics_secure',
#  'product_smart_meter_booking',
#  'product_smart_meter_booking_secure',
#  'product_smint',
#  'product_smint_secure',
#  'raw_always_on',
#  'raw_andromeda',
#  'raw_andromeda_secure',
#  'raw_bast',
#  'raw_bast_secure',
#  'raw_bc_ovo_applications',
#  'raw_bc_ovo_applications_secure',
#  'raw_boost',
#  'raw_boost_secure',
#  'raw_cepheus',
#  'raw_cepheus_secure',
#  'raw_chimps',
#  'raw_chimps_secure',
#  'raw_corgi_hp',
#  'raw_corgi_hp_secure',
#  'raw_crm_secure',
#  'raw_ecoes_secure',
#  'raw_employee',
#  'raw_energy_insights',
#  'raw_energyhelpline',
#  'raw_ensek_financial',
#  'raw_fieldservicestech',
#  'raw_fieldservicestech_secure',
#  'raw_flows',
#  'raw_flows_secure',
#  'raw_gen_prod',
#  'raw_gen_prod_secure',
#  'raw_homemoves',
#  'raw_homemoves_secure',
#  'raw_i3_ic_2015_prd_secure',
#  'raw_identity_secure',
#  'raw_jaws',
#  'raw_jaws_secure',
#  'raw_lumo',
#  'raw_lumo_secure',
#  'raw_mis',
#  'raw_mis_secure',
#  'raw_oot',
#  'raw_oot_secure',
#  'raw_ops_workstreams',
#  'raw_orex',
#  'raw_orex_secure',
#  'raw_orion',
#  'raw_orion_migration',
#  'raw_orion_migration_secure',
#  'raw_orion_onboarding',
#  'raw_orion_onboarding_secure',
#  'raw_orion_secure',
#  'raw_pace',
#  'raw_pace_secure',
#  'raw_payments',
#  'raw_payments_secure',
#  'raw_priority_service_register',
#  'raw_priority_service_register_secure',
#  'raw_smart_meter_booking',
#  'raw_smart_meter_booking_secure',
#  'raw_smint',
#  'raw_smint_secure',
#  'raw_sre',
#  'raw_sre_secure',
#  'reference',
#  'reference_secure',
#  'reporting_activos',
#  'reporting_additional_products',
#  'reporting_address_secure',
#  'reporting_billing',
#  'reporting_contact',
#  'reporting_contracts',
#  'reporting_crm',
#  'reporting_employee_secure',
#  'reporting_finance',
#  'reporting_finance_secure',
#  'reporting_iht',
#  'reporting_letters',
#  'reporting_mart',
#  'reporting_meters',
#  'reporting_meters_secure',
#  'reporting_mosaic',
#  'reporting_operations',
#  'reporting_orders',
#  'reporting_process',
#  'reporting_sales',
#  'reporting_sales_secure',
#  'reporting_tariffs',
#  'reporting_utiliserve',
#  'sandbox_credit_secure',
#  'sandbox_ovo_customer_ops_secure',
#  'sandbox_trading_secure',
#  'slo',
#  'staging_reporting_additional_products',
#  'staging_reporting_address_secure',
#  'staging_reporting_billing',
#  'staging_reporting_contact',
#  'staging_reporting_contracts',
#  'staging_reporting_crm',
#  'staging_reporting_finance',
#  'staging_reporting_finance_secure',
#  'staging_reporting_letters',
#  'staging_reporting_mart',
#  'staging_reporting_meters',
#  'staging_reporting_mosaic',
#  'staging_reporting_mosaic_secure',
#  'staging_reporting_operations',
#  'staging_reporting_orders',
#  'staging_reporting_process',
#  'staging_reporting_sales',
#  'staging_reporting_tariffs']

# %%
#Other way of creating the Client

#client = bigquery.Client.from_service_account_json("andromeda-data-nonprod-82f7cce7a980.json")
# datasets = [dataset.dataset_id for dataset in client.list_datasets() if not dataset.dataset_id.startswith('u_')]
# print(len(datasets))
# datasets

# %%
#How to list tables/views inside of a given dataset. In this case I've used landing_andromeda. 
#I am using a harcoded query for that but I imagine there will be something more fit for purpose inside the API documentation
#similar to to the 'client.list_datasets()' we used before. Maybe something like 'dataset.list_objects()'? Worth exploring


sql1 = ("""
SELECT * FROM `data-engineering-prod.landing_andromeda.__TABLES__` WHERE table_id LIKE 'rac_flow%'
""")

df1 = pd.read_gbq(query = sql1, project_id = "data-engineering-prod", dialect = "standard")
df1.head()
# Out:
# Downloading: 100%|██████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 217.92rows/s]
#               project_id         dataset_id                    table_id  \
# 0  data-engineering-prod  landing_andromeda  rac_flow_d0010_received_v2
# 1  data-engineering-prod  landing_andromeda  rac_flow_d0010_received_v4
# 2  data-engineering-prod  landing_andromeda  rac_flow_d0010_received_v5
# 3  data-engineering-prod  landing_andromeda  rac_flow_d0010_received_v6
# 4  data-engineering-prod  landing_andromeda  rac_flow_d0010_received_v7
#
#    creation_time  last_modified_time  row_count  size_bytes  type
# 0  1528822633623       1538437721914          0           0     2
# 1  1528822637424       1538437725123          0           0     2
# 2  1528822641509       1538437728414          0           0     2
# 3  1528822645453       1538437732215          0           0     2
# 4  1528822649749       1538437735271          0           0     2

# %%
#List of all table_id

topic_list = [i for i in df1.table_id]
topic_list
# Out:
# ['rac_flow_d0010_received_v2',
#  'rac_flow_d0010_received_v4',
#  'rac_flow_d0010_received_v5',
#  'rac_flow_d0010_received_v6',
#  'rac_flow_d0010_received_v7',
#  'rac_flow_d0010_received_v8',
#  'rac_flow_d0010_received_v9',
#  'rac_flow_d0019_received_v1',
#  'rac_flow_d0019_received_v2',
#  'rac_flow_d0086_received_v2',
#  'rac_flow_d0086_received_v3',
#  'rac_flow_d0086_received_v4',
#  'rac_flow_d0149_received_v3',
#  'rac_flow_d0149_received_v4',
#  'rac_flow_d0150_received_v3',
#  'rac_flow_d0150_received_v4',
#  'rac_flow_d0150_received_v5',
#  'rac_flow_d0188_received_v1',
#  'rac_flow_d0188_received_v2',
#  'rac_flow_d0188_received_v3',
#  'rac_flow_d0217_received_v2',
#  'rac_flow_d0303_received_v3',
#  'rac_flow_d0303_received_v4',
#  'rac_flow_d0303_received_v5',
#  'rac_flow_d0311_received_v3',
#  'rac_flow_d0311_received_v4',
#  'rac_flow_mri_received_v1',
#  'rac_flow_mri_received_v2',
#  'rac_flow_nrl_received_v1',
#  'rac_flow_trf_received_v1']

# %%
#!bq ls --project_id data-engineering-prod

# %%
#Another way of getting the list of datasets using cmd commands. I did this when I had no clue about the API

cmd = 'bq ls --max_results=10000 --project_id data-engineering-prod'

out = subprocess.Popen(cmd.split(), 
           stdout=subprocess.PIPE, 
           stderr=subprocess.STDOUT,
           shell=True)
stdout,stderr = out.communicate()

dataset_list = [stdout.split()[i].decode() for i in np.arange(2,len(stdout.split())) ]
dataset_list = [i for i in dataset_list if not i.startswith('u_')]
print(len(dataset_list))
dataset_list
# Out:
# 196
# ['CRM',
#  'CRM_internal',
#  'alignment_orion',
#  'alignment_orion_secure',
#  'auto_capture',
#  'auto_capture_v2',
#  'auto_capture_v2_secure',
#  'bigquery_reports',
#  'cs_agent_scorecard_secure',
#  'custom_crm_secure',
#  'custom_energy_ops_process_development',
#  'custom_insight',
#  'custom_ops_reporting',
#  'custom_ops_reporting_secure',
#  'custom_regulatory',
#  'deltaforce_audit',
#  'deltaforce_data_migration_temp',
#  'energy_platform_secure',
#  'exception_monitoring',
#  'landing_acquisitions',
#  'landing_acquisitions_secure',
#  'landing_andromeda',
#  'landing_andromeda_secure',
#  'landing_apollo_cx',
#  'landing_apollo_cx_secure',
#  'landing_apollo_opex',
#  'landing_apollo_opex_secure',
#  'landing_bast',
#  'landing_bast_secure',
#  'landing_bc_ovo_applications',
#  'landing_bc_ovo_applications_secure',
#  'landing_boost',
#  'landing_boost_secure',
#  'landing_brand_nps_secure',
#  'landing_cepheus',
#  'landing_cepheus_secure',
#  'landing_comms',
#  'landing_comms_secure',
#  'landing_crm',
#  'landing_crm_secure',
#  'landing_employee_secure',
#  'landing_energyhelpline',
#  'landing_experian',
#  'landing_flows',
#  'landing_flows_secure',
#  'landing_gen_preprod_secure',
#  'landing_gen_prod_secure',
#  'landing_i3_ic_2015_prd',
#  'landing_i3_ic_2015_prd_secure',
#  'landing_identity',
#  'landing_identity_secure',
#  'landing_iht',
#  'landing_oot',
#  'landing_oot_secure',
#  'landing_orex',
#  'landing_orex_secure',
#  'landing_orion',
#  'landing_orion_migration',
#  'landing_orion_migration_secure',
#  'landing_orion_secure',
#  'landing_ovo_france_identity',
#  'landing_ovo_france_identity_secure',
#  'landing_payments',
#  'landing_payments_secure',
#  'landing_priority_service_register',
#  'landing_priority_service_register_secure',
#  'landing_propositions',
#  'landing_propositions_secure',
#  'landing_smart_meter_asset',
#  'landing_smart_meter_asset_secure',
#  'landing_smart_meter_booking',
#  'landing_smart_meter_booking_secure',
#  'landing_smint',
#  'landing_smint_secure',
#  'landing_sre',
#  'landing_sre_secure',
#  'landing_storage_gen',
#  'landing_storage_gen_secure',
#  'landing_utiliserve',
#  'logs_bigquery',
#  'logs_kubernetes_v2',
#  'mis_manual_exports',
#  'orion_eligibility',
#  'product_andromeda_secure',
#  'product_bast_secure',
#  'product_brand_nps',
#  'product_corgi',
#  'product_crm',
#  'product_crm_secure',
#  'product_digital_support_experience_secure',
#  'product_energyhelpline',
#  'product_identity_secure',
#  'product_orion',
#  'product_orion_secure',
#  'product_ovo_mobile_app',
#  'product_payments',
#  'product_payments_secure',
#  'product_smart_meter_booking',
#  'product_smart_meter_booking_secure',
#  'product_smint',
#  'product_smint_secure',
#  'public',
#  'public_secure',
#  'raw_always_on',
#  'raw_andromeda',
#  'raw_andromeda_secure',
#  'raw_bast',
#  'raw_bast_secure',
#  'raw_bc_ovo_applications',
#  'raw_bc_ovo_applications_secure',
#  'raw_boost',
#  'raw_boost_secure',
#  'raw_cepheus',
#  'raw_cepheus_secure',
#  'raw_chimps',
#  'raw_chimps_secure',
#  'raw_corgi_hp',
#  'raw_corgi_hp_secure',
#  'raw_crm_secure',
#  'raw_ecoes_secure',
#  'raw_employee',
#  'raw_energy_insights',
#  'raw_energyhelpline',
#  'raw_ensek_financial',
#  'raw_flows',
#  'raw_flows_secure',
#  'raw_gen_prod',
#  'raw_gen_prod_secure',
#  'raw_i3_ic_2015_prd_secure',
#  'raw_identity_secure',
#  'raw_lumo',
#  'raw_lumo_secure',
#  'raw_mis',
#  'raw_mis_secure',
#  'raw_oot',
#  'raw_oot_secure',
#  'raw_ops_workstreams',
#  'raw_orex',
#  'raw_orex_secure',
#  'raw_orion',
#  'raw_orion_migration',
#  'raw_orion_migration_secure',
#  'raw_orion_secure',
#  'raw_payments',
#  'raw_payments_secure',
#  'raw_priority_service_register',
#  'raw_priority_service_register_secure',
#  'raw_smart_meter_asset',
#  'raw_smart_meter_asset_secure',
#  'raw_smart_meter_booking',
#  'raw_smart_meter_booking_secure',
#  'raw_smint',
#  'raw_smint_secure',
#  'raw_sre',
#  'raw_sre_secure',
#  'reference',
#  'reporting_activos',
#  'reporting_additional_products',
#  'reporting_address_secure',
#  'reporting_billing',
#  'reporting_contact',
#  'reporting_contracts',
#  'reporting_crm',
#  'reporting_employee_secure',
#  'reporting_finance',
#  'reporting_iht',
#  'reporting_letters',
#  'reporting_mart',
#  'reporting_meters',
#  'reporting_meters_secure',
#  'reporting_operations',
#  'reporting_orders',
#  'reporting_process',
#  'reporting_sales',
#  'reporting_tariffs',
#  'reporting_utiliserve',
#  'reporting_vulnerabilities_secure',
#  'sandbox_credit_secure',
#  'sandbox_ovo_customer_ops_secure',
#  'sandbox_trading_secure',
#  'slo',
#  'staging_reporting_additional_products',
#  'staging_reporting_address_secure',
#  'staging_reporting_billing',
#  'staging_reporting_contact',
#  'staging_reporting_contracts',
#  'staging_reporting_crm',
#  'staging_reporting_finance',
#  'staging_reporting_letters',
#  'staging_reporting_mart',
#  'staging_reporting_meters',
#  'staging_reporting_operations',
#  'staging_reporting_orders',
#  'staging_reporting_process',
#  'staging_reporting_sales',
#  'staging_reporting_tariffs']

# %%
#From this cell onwards, I am trying to find who (users) are using amy of the tables inside the list "topic_list". 
#I am also finding what views use those tables in their logic. 
#This is probably out of the scope at the moment but it will be useful at some point

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import subprocess
import os
import pandas_gbq as pgbq

#list of tables for which we want to check dependencies
legacy_topics = topic_list

#get all datasets under data-engineering-prod
cmd = 'bq ls --max_results=10000 --project_id data-engineering-prod'

out = subprocess.Popen(cmd.split(), 
           stdout=subprocess.PIPE, 
           stderr=subprocess.STDOUT,
           shell=True)
stdout,stderr = out.communicate()

dataset_list = [stdout.split()[i].decode() for i in np.arange(2,len(stdout.split()))]
dataset_list = [i for i in dataset_list if not i.startswith('u_')]

#dataset_list = ['auto_capture_v2_secure']




l = []
count = 1

for topic in legacy_topics:
    
    
    print(topic+f" {count} out of {len(legacy_topics)}")
    
    for dataset in dataset_list:    
        
        d = {}
        d["legacy_view"] = topic
        
        
        try:
    
            sql5 = (f"""
                    SELECT 
                     CONCAT(table_catalog,'.',table_schema,'.',table_name) AS view
                    FROM
                     `data-engineering-prod.{dataset}.INFORMATION_SCHEMA.VIEWS`
                    WHERE view_definition LIKE '%{topic}%'
                    AND view_definition NOT LIKE r'%{topic}\_%'
                    """)

            df5 = pd.read_gbq(query = sql5, project_id = "data-engineering-prod", dialect = "standard")
            views = list(df5["view"])
            
            d["dataset"] = dataset    


            if views:    

                d["views"] = []

                for view in views:
                    
                    d["views"].append(view)
                    
        except pgbq.gbq.GenericGBQException:
            
            d["dataset"] = dataset
            d["views"] = "Access Denied to Dataset"
            
        l.append(d)
        
    count += 1
        
        #log
        #print("    "+dataset)    

print("\nRun completed")        
pd.DataFrame(l).to_json("views_dependencies.json")
# Out:
# rac_flow_d0010_received_v2 1 out of 30
# rac_flow_d0010_received_v4 2 out of 30
# rac_flow_d0010_received_v5 3 out of 30
# rac_flow_d0010_received_v6 4 out of 30
# rac_flow_d0010_received_v7 5 out of 30
# rac_flow_d0010_received_v8 6 out of 30
# rac_flow_d0010_received_v9 7 out of 30
# rac_flow_d0019_received_v1 8 out of 30
# rac_flow_d0019_received_v2 9 out of 30
# rac_flow_d0086_received_v2 10 out of 30
# rac_flow_d0086_received_v3 11 out of 30
# rac_flow_d0086_received_v4 12 out of 30
# rac_flow_d0149_received_v3 13 out of 30
# rac_flow_d0149_received_v4 14 out of 30
# rac_flow_d0150_received_v3 15 out of 30
# rac_flow_d0150_received_v4 16 out of 30
# rac_flow_d0150_received_v5 17 out of 30
# rac_flow_d0188_received_v1 18 out of 30
# rac_flow_d0188_received_v2 19 out of 30
# rac_flow_d0188_received_v3 20 out of 30
# rac_flow_d0217_received_v2 21 out of 30
# rac_flow_d0303_received_v3 22 out of 30
# rac_flow_d0303_received_v4 23 out of 30
# rac_flow_d0303_received_v5 24 out of 30
# rac_flow_d0311_received_v3 25 out of 30
# rac_flow_d0311_received_v4 26 out of 30
# rac_flow_mri_received_v1 27 out of 30
# rac_flow_mri_received_v2 28 out of 30
# rac_flow_nrl_received_v1 29 out of 30
# rac_flow_trf_received_v1 30 out of 30
#
# Run completed

# %%
pd.read_json("views_dependencies.json")
# Out:
#                            dataset                 legacy_view  \
# 0                              CRM  rac_flow_d0010_received_v2
# 1                     CRM_internal  rac_flow_d0010_received_v2
# 2                  alignment_orion  rac_flow_d0010_received_v2
# 3           alignment_orion_secure  rac_flow_d0010_received_v2
# 4                     auto_capture  rac_flow_d0010_received_v2
# ...                            ...                         ...
# 5875  staging_reporting_operations    rac_flow_trf_received_v1
# 5876      staging_reporting_orders    rac_flow_trf_received_v1
# 5877     staging_reporting_process    rac_flow_trf_received_v1
# 5878       staging_reporting_sales    rac_flow_trf_received_v1
# 5879     staging_reporting_tariffs    rac_flow_trf_received_v1
#
#                          views
# 0     Access Denied to Dataset
# 1     Access Denied to Dataset
# 2                         None
# 3     Access Denied to Dataset
# 4     Access Denied to Dataset
# ...                        ...
# 5875                      None
# 5876                      None
# 5877                      None
# 5878                      None
# 5879                      None
#
# [5880 rows x 3 columns]

# %%
pd.set_option('display.max_colwidth', None)

df = pd.read_json("views_dependencies.json")
df = df[~((df["views"] == "Access Denied to Dataset") | (df["views"].isnull()))]
df = df.explode("views")
df
# Out:
#                        dataset                 legacy_view  \
# 21           landing_andromeda  rac_flow_d0010_received_v2
# 101                     public  rac_flow_d0010_received_v2
# 217          landing_andromeda  rac_flow_d0010_received_v4
# 297                     public  rac_flow_d0010_received_v4
# 413          landing_andromeda  rac_flow_d0010_received_v5
# ...                        ...                         ...
# 5509         landing_andromeda    rac_flow_nrl_received_v1
# 5510  landing_andromeda_secure    rac_flow_nrl_received_v1
# 5589                    public    rac_flow_nrl_received_v1
# 5705         landing_andromeda    rac_flow_trf_received_v1
# 5785                    public    rac_flow_trf_received_v1
#
#                                                                         views
# 21         data-engineering-prod.landing_andromeda.rac_flow_d0010_received_v2
# 101                   data-engineering-prod.public.rac_flow_d0010_received_v2
# 217        data-engineering-prod.landing_andromeda.rac_flow_d0010_received_v4
# 297                   data-engineering-prod.public.rac_flow_d0010_received_v4
# 413        data-engineering-prod.landing_andromeda.rac_flow_d0010_received_v5
# ...                                                                       ...
# 5509         data-engineering-prod.landing_andromeda.rac_flow_nrl_received_v1
# 5510  data-engineering-prod.landing_andromeda_secure.rac_flow_nrl_received_v1
# 5589                    data-engineering-prod.public.rac_flow_nrl_received_v1
# 5705         data-engineering-prod.landing_andromeda.rac_flow_trf_received_v1
# 5785                    data-engineering-prod.public.rac_flow_trf_received_v1
#
# [63 rows x 3 columns]

# %%
list_views = [i for i in df["views"]] + [i for i in df["legacy_view"]]
list_views
# Out:
# ['data-engineering-prod.landing_andromeda.rac_flow_d0010_received_v2',
#  'data-engineering-prod.public.rac_flow_d0010_received_v2',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0010_received_v4',
#  'data-engineering-prod.public.rac_flow_d0010_received_v4',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0010_received_v5',
#  'data-engineering-prod.public.rac_flow_d0010_received_v5',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0010_received_v6',
#  'data-engineering-prod.public.rac_flow_d0010_received_v6',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0010_received_v7',
#  'data-engineering-prod.public.rac_flow_d0010_received_v7',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0010_received_v8',
#  'data-engineering-prod.public.rac_flow_d0010_received_v8',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0010_received_v9',
#  'data-engineering-prod.product_andromeda_secure.rac_d10_simplified',
#  'data-engineering-prod.public.rac_flow_d0010_received_v9',
#  'data-engineering-prod.raw_andromeda_secure.rac_flow_d0010_received',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0019_received_v1',
#  'data-engineering-prod.public.rac_flow_d0019_received_v1',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0019_received_v2',
#  'data-engineering-prod.public.rac_flow_d0019_received_v2',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0086_received_v2',
#  'data-engineering-prod.public.rac_flow_d0086_received_v2',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0086_received_v3',
#  'data-engineering-prod.public.rac_flow_d0086_received_v3',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0086_received_v4',
#  'data-engineering-prod.public.rac_flow_d0086_received_v4',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0149_received_v3',
#  'data-engineering-prod.public.rac_flow_d0149_received_v3',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0149_received_v4',
#  'data-engineering-prod.public.rac_flow_d0149_received_v4',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0150_received_v3',
#  'data-engineering-prod.public.rac_flow_d0150_received_v3',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0150_received_v4',
#  'data-engineering-prod.public.rac_flow_d0150_received_v4',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0150_received_v5',
#  'data-engineering-prod.public.rac_flow_d0150_received_v5',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0188_received_v1',
#  'data-engineering-prod.public.rac_flow_d0188_received_v1',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0188_received_v2',
#  'data-engineering-prod.public.rac_flow_d0188_received_v2',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0188_received_v3',
#  'data-engineering-prod.public.rac_flow_d0188_received_v3',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0217_received_v2',
#  'data-engineering-prod.public.rac_flow_d0217_received_v2',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0303_received_v3',
#  'data-engineering-prod.public.rac_flow_d0303_received_v3',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0303_received_v4',
#  'data-engineering-prod.public.rac_flow_d0303_received_v4',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0303_received_v5',
#  'data-engineering-prod.public.rac_flow_d0303_received_v5',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0311_received_v3',
#  'data-engineering-prod.public.rac_flow_d0311_received_v3',
#  'data-engineering-prod.landing_andromeda.rac_flow_d0311_received_v4',
#  'data-engineering-prod.public.rac_flow_d0311_received_v4',
#  'data-engineering-prod.landing_andromeda.rac_flow_mri_received_v1',
#  'data-engineering-prod.public.rac_flow_mri_received_v1',
#  'data-engineering-prod.landing_andromeda.rac_flow_mri_received_v2',
#  'data-engineering-prod.public.rac_flow_mri_received_v2',
#  'data-engineering-prod.landing_andromeda.rac_flow_nrl_received_v1',
#  'data-engineering-prod.landing_andromeda_secure.rac_flow_nrl_received_v1',
#  'data-engineering-prod.public.rac_flow_nrl_received_v1',
#  'data-engineering-prod.landing_andromeda.rac_flow_trf_received_v1',
#  'data-engineering-prod.public.rac_flow_trf_received_v1',
#  'rac_flow_d0010_received_v2',
#  'rac_flow_d0010_received_v2',
#  'rac_flow_d0010_received_v4',
#  'rac_flow_d0010_received_v4',
#  'rac_flow_d0010_received_v5',
#  'rac_flow_d0010_received_v5',
#  'rac_flow_d0010_received_v6',
#  'rac_flow_d0010_received_v6',
#  'rac_flow_d0010_received_v7',
#  'rac_flow_d0010_received_v7',
#  'rac_flow_d0010_received_v8',
#  'rac_flow_d0010_received_v8',
#  'rac_flow_d0010_received_v9',
#  'rac_flow_d0010_received_v9',
#  'rac_flow_d0010_received_v9',
#  'rac_flow_d0010_received_v9',
#  'rac_flow_d0019_received_v1',
#  'rac_flow_d0019_received_v1',
#  'rac_flow_d0019_received_v2',
#  'rac_flow_d0019_received_v2',
#  'rac_flow_d0086_received_v2',
#  'rac_flow_d0086_received_v2',
#  'rac_flow_d0086_received_v3',
#  'rac_flow_d0086_received_v3',
#  'rac_flow_d0086_received_v4',
#  'rac_flow_d0086_received_v4',
#  'rac_flow_d0149_received_v3',
#  'rac_flow_d0149_received_v3',
#  'rac_flow_d0149_received_v4',
#  'rac_flow_d0149_received_v4',
#  'rac_flow_d0150_received_v3',
#  'rac_flow_d0150_received_v3',
#  'rac_flow_d0150_received_v4',
#  'rac_flow_d0150_received_v4',
#  'rac_flow_d0150_received_v5',
#  'rac_flow_d0150_received_v5',
#  'rac_flow_d0188_received_v1',
#  'rac_flow_d0188_received_v1',
#  'rac_flow_d0188_received_v2',
#  'rac_flow_d0188_received_v2',
#  'rac_flow_d0188_received_v3',
#  'rac_flow_d0188_received_v3',
#  'rac_flow_d0217_received_v2',
#  'rac_flow_d0217_received_v2',
#  'rac_flow_d0303_received_v3',
#  'rac_flow_d0303_received_v3',
#  'rac_flow_d0303_received_v4',
#  'rac_flow_d0303_received_v4',
#  'rac_flow_d0303_received_v5',
#  'rac_flow_d0303_received_v5',
#  'rac_flow_d0311_received_v3',
#  'rac_flow_d0311_received_v3',
#  'rac_flow_d0311_received_v4',
#  'rac_flow_d0311_received_v4',
#  'rac_flow_mri_received_v1',
#  'rac_flow_mri_received_v1',
#  'rac_flow_mri_received_v2',
#  'rac_flow_mri_received_v2',
#  'rac_flow_nrl_received_v1',
#  'rac_flow_nrl_received_v1',
#  'rac_flow_nrl_received_v1',
#  'rac_flow_trf_received_v1',
#  'rac_flow_trf_received_v1']

# %%
col_names =  ['view_queried', 'user', 'number_queries']
df_users  = pd.DataFrame(columns = col_names)

for view in list_views:

    sql1 = (f"""

      WITH cte1 AS(    
      SELECT '{view}' AS view_queried, Query_Timestamp, Query_Initiator, Query_SQL 
      FROM `data-engineering-prod.logs_bigquery.data_access_friendly`
      WHERE Query_SQL LIKE '%{view}%'
      AND Query_SQL NOT LIKE r'%{view}\_%'
      )

      SELECT view_queried, Query_Initiator AS user, COUNT(Query_SQL) AS number_queries
      FROM cte1
      GROUP BY view_queried, Query_Initiator 
    
    """)

    df2 = pd.read_gbq(query = sql1, project_id = "data-engineering-prod", dialect = "standard")
    
    df_users = df_users.append(df2)
# Out:
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.35rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.73rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.49rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.83rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.99rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.37rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.01rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.37rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.43rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.50rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.71rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 0rows [00:00, ?rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  8.52rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 18.77rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 18.67rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 10.22rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 16.46rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.35rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 18.41rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.88rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  9.26rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 16.85rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 10.78rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 20.46rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 33.68rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 19.52rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 35.19rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 41.24rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 15.92rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  9.55rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 32.09rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 34.78rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.09rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.58rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 16.76rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.90rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 26.85rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 10.95rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 18.57rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.15rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 25.21rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 30.36rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 11.65rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  8.24rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 15.67rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.18rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  9.32rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:04<00:00,  1.62s/rows]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.16rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 35.02rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.93rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 31.07rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 34.86rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.10rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 20.19rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 14.32rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 12.91rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 20.68rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 16.58rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 18.83rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 16.57rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 15.08rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.90rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 16.27rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 24.63rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 28.36rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 14.53rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 31.31rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 24.61rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 28.91rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.37rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.29rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 21.32rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 19.84rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.29rows/s]

# %%
df_users.to_csv("data_users_rac_flows.csv", index=False)

# %%
pd.set_option('display.max_rows', None)
df_users = pd.read_csv("data_users_rac_flows.csv")
df_users[df_users['user']!='victor.irles@ovoenergy.com'].sort_values(by=['view_queried','number_queries'], ascending=[True, False])
# Out:
#                                                            view_queried  \
# 0    data-engineering-prod.landing_andromeda.rac_flow_d0010_received_v9
# 2    data-engineering-prod.landing_andromeda.rac_flow_d0019_received_v2
# 6    data-engineering-prod.landing_andromeda.rac_flow_d0188_received_v1
# 7    data-engineering-prod.landing_andromeda.rac_flow_d0188_received_v2
# 8    data-engineering-prod.landing_andromeda.rac_flow_d0188_received_v3
# 10   data-engineering-prod.landing_andromeda.rac_flow_d0311_received_v4
# 1               data-engineering-prod.public.rac_flow_d0010_received_v9
# 3               data-engineering-prod.public.rac_flow_d0019_received_v2
# 4               data-engineering-prod.public.rac_flow_d0149_received_v4
# 5               data-engineering-prod.public.rac_flow_d0150_received_v5
# 9               data-engineering-prod.public.rac_flow_d0217_received_v2
# 12                                           rac_flow_d0010_received_v2
# 14                                           rac_flow_d0010_received_v2
# 15                                           rac_flow_d0010_received_v4
# 17                                           rac_flow_d0010_received_v4
# 19                                           rac_flow_d0010_received_v5
# 21                                           rac_flow_d0010_received_v5
# 23                                           rac_flow_d0010_received_v6
# 26                                           rac_flow_d0010_received_v6
# 28                                           rac_flow_d0010_received_v7
# 30                                           rac_flow_d0010_received_v7
# 31                                           rac_flow_d0010_received_v8
# 33                                           rac_flow_d0010_received_v8
# 35                                           rac_flow_d0010_received_v9
# 39                                           rac_flow_d0010_received_v9
# 44                                           rac_flow_d0010_received_v9
# 49                                           rac_flow_d0010_received_v9
# 36                                           rac_flow_d0010_received_v9
# 40                                           rac_flow_d0010_received_v9
# 45                                           rac_flow_d0010_received_v9
# 50                                           rac_flow_d0010_received_v9
# 37                                           rac_flow_d0010_received_v9
# 41                                           rac_flow_d0010_received_v9
# 43                                           rac_flow_d0010_received_v9
# 48                                           rac_flow_d0010_received_v9
# 51                                           rac_flow_d0019_received_v1
# 54                                           rac_flow_d0019_received_v1
# 55                                           rac_flow_d0019_received_v2
# 61                                           rac_flow_d0019_received_v2
# 58                                           rac_flow_d0019_received_v2
# 59                                           rac_flow_d0019_received_v2
# 56                                           rac_flow_d0019_received_v2
# 62                                           rac_flow_d0019_received_v2
# 63                                           rac_flow_d0086_received_v2
# 66                                           rac_flow_d0086_received_v2
# 67                                           rac_flow_d0086_received_v3
# 69                                           rac_flow_d0086_received_v3
# 73                                           rac_flow_d0086_received_v4
# 75                                           rac_flow_d0086_received_v4
# 72                                           rac_flow_d0086_received_v4
# 76                                           rac_flow_d0086_received_v4
# 77                                           rac_flow_d0149_received_v3
# 79                                           rac_flow_d0149_received_v3
# 81                                           rac_flow_d0149_received_v4
# 86                                           rac_flow_d0149_received_v4
# 82                                           rac_flow_d0149_received_v4
# 85                                           rac_flow_d0149_received_v4
# 87                                           rac_flow_d0150_received_v3
# 90                                           rac_flow_d0150_received_v3
# 92                                           rac_flow_d0150_received_v4
# 93                                           rac_flow_d0150_received_v4
# 95                                           rac_flow_d0150_received_v5
# 98                                           rac_flow_d0150_received_v5
# 96                                           rac_flow_d0150_received_v5
# 100                                          rac_flow_d0150_received_v5
# 104                                          rac_flow_d0188_received_v1
# 107                                          rac_flow_d0188_received_v1
# 103                                          rac_flow_d0188_received_v1
# 105                                          rac_flow_d0188_received_v1
# 101                                          rac_flow_d0188_received_v1
# 108                                          rac_flow_d0188_received_v1
# 112                                          rac_flow_d0188_received_v2
# 116                                          rac_flow_d0188_received_v2
# 109                                          rac_flow_d0188_received_v2
# 113                                          rac_flow_d0188_received_v2
# 111                                          rac_flow_d0188_received_v2
# 115                                          rac_flow_d0188_received_v2
# 118                                          rac_flow_d0188_received_v3
# 123                                          rac_flow_d0188_received_v3
# 120                                          rac_flow_d0188_received_v3
# 124                                          rac_flow_d0188_received_v3
# 117                                          rac_flow_d0188_received_v3
# 122                                          rac_flow_d0188_received_v3
# 126                                          rac_flow_d0217_received_v2
# 129                                          rac_flow_d0217_received_v2
# 127                                          rac_flow_d0217_received_v2
# 128                                          rac_flow_d0217_received_v2
# 131                                          rac_flow_d0303_received_v3
# 134                                          rac_flow_d0303_received_v3
# 136                                          rac_flow_d0303_received_v4
# 138                                          rac_flow_d0303_received_v4
# 140                                          rac_flow_d0303_received_v5
# 142                                          rac_flow_d0303_received_v5
# 143                                          rac_flow_d0311_received_v3
# 145                                          rac_flow_d0311_received_v3
# 149                                          rac_flow_d0311_received_v4
# 151                                          rac_flow_d0311_received_v4
# 147                                          rac_flow_d0311_received_v4
# 152                                          rac_flow_d0311_received_v4
# 155                                            rac_flow_mri_received_v1
# 156                                            rac_flow_mri_received_v1
# 153                                            rac_flow_mri_received_v1
# 158                                            rac_flow_mri_received_v1
# 160                                            rac_flow_mri_received_v2
# 164                                            rac_flow_mri_received_v2
# 161                                            rac_flow_mri_received_v2
# 163                                            rac_flow_mri_received_v2
# 166                                            rac_flow_nrl_received_v1
# 168                                            rac_flow_nrl_received_v1
# 169                                            rac_flow_nrl_received_v1
# 172                                            rac_flow_trf_received_v1
# 173                                            rac_flow_trf_received_v1
#
#                                                                             user  \
# 0                                                     james.baglin@ovoenergy.com
# 2                                                    roman.langolf@ovoenergy.com
# 6                                                      phil.hather@ovoenergy.com
# 7                                                      phil.hather@ovoenergy.com
# 8                                                      phil.hather@ovoenergy.com
# 10                                                 anthony.chadney@ovoenergy.com
# 1                                                        harry.may@ovoenergy.com
# 3                                               joana.salkauskaite@ovoenergy.com
# 4                                                         joe.dwek@ovoenergy.com
# 5                                                         joe.dwek@ovoenergy.com
# 9                                                denitsa.damyanova@ovoenergy.com
# 12   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 14   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 15   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 17   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 19   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 21   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 23   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 26   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 28   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 30   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 31   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 33   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 35   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 39   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 44   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 49   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 36                                                       harry.may@ovoenergy.com
# 40                                                       harry.may@ovoenergy.com
# 45                                                       harry.may@ovoenergy.com
# 50                                                       harry.may@ovoenergy.com
# 37                                                    james.baglin@ovoenergy.com
# 41                                                    james.baglin@ovoenergy.com
# 43                                                    james.baglin@ovoenergy.com
# 48                                                    james.baglin@ovoenergy.com
# 51   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 54   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 55   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 61   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 58                                                   roman.langolf@ovoenergy.com
# 59                                                   roman.langolf@ovoenergy.com
# 56                                              joana.salkauskaite@ovoenergy.com
# 62                                              joana.salkauskaite@ovoenergy.com
# 63   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 66   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 67   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 69   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 73   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 75   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 72                                                graham.bradfield@ovoenergy.com
# 76                                                graham.bradfield@ovoenergy.com
# 77   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 79   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 81   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 86   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 82                                                        joe.dwek@ovoenergy.com
# 85                                                        joe.dwek@ovoenergy.com
# 87   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 90   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 92   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 93   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 95   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 98   ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 96                                                        joe.dwek@ovoenergy.com
# 100                                                       joe.dwek@ovoenergy.com
# 104  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 107  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 103                                                    phil.hather@ovoenergy.com
# 105                                                    phil.hather@ovoenergy.com
# 101                                                 tristan.crudge@ovoenergy.com
# 108                                                 tristan.crudge@ovoenergy.com
# 112  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 116  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 109                                                    phil.hather@ovoenergy.com
# 113                                                    phil.hather@ovoenergy.com
# 111                                                 tristan.crudge@ovoenergy.com
# 115                                                 tristan.crudge@ovoenergy.com
# 118  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 123  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 120                                                    phil.hather@ovoenergy.com
# 124                                                    phil.hather@ovoenergy.com
# 117                                                 tristan.crudge@ovoenergy.com
# 122                                                 tristan.crudge@ovoenergy.com
# 126  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 129  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 127                                              denitsa.damyanova@ovoenergy.com
# 128                                              denitsa.damyanova@ovoenergy.com
# 131  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 134  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 136  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 138  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 140  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 142  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 143  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 145  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 149  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 151  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 147                                                anthony.chadney@ovoenergy.com
# 152                                                anthony.chadney@ovoenergy.com
# 155  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 156  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 153                                                  harriet.mason@ovoenergy.com
# 158                                                  harriet.mason@ovoenergy.com
# 160  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 164  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 161                                                  harriet.mason@ovoenergy.com
# 163                                                  harriet.mason@ovoenergy.com
# 166  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 168  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 169  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 172  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
# 173  ovo-prd-bq-duplicate-reporter@data-engineering-prod.iam.gserviceaccount.com
#
#      number_queries
# 0                 1
# 2                 5
# 6                13
# 7                25
# 8                23
# 10                1
# 1                 2
# 3                 1
# 4                11
# 5                41
# 9                 1
# 12               78
# 14               78
# 15               78
# 17               78
# 19               78
# 21               78
# 23               78
# 26               78
# 28               78
# 30               78
# 31               78
# 33               78
# 35              111
# 39              111
# 44              111
# 49              111
# 36                2
# 40                2
# 45                2
# 50                2
# 37                1
# 41                1
# 43                1
# 48                1
# 51               78
# 54               78
# 55              156
# 61              156
# 58                5
# 59                5
# 56                1
# 62                1
# 63               78
# 66               78
# 67               78
# 69               78
# 73              126
# 75              126
# 72                7
# 76                7
# 77               78
# 79               78
# 81              156
# 86              156
# 82               11
# 85               11
# 87               78
# 90               78
# 92               78
# 93               78
# 95              156
# 98              156
# 96               41
# 100              41
# 104              78
# 107              78
# 103              13
# 105              13
# 101               1
# 108               1
# 112              78
# 116              78
# 109              25
# 113              25
# 111               1
# 115               1
# 118             126
# 123             126
# 120              23
# 124              23
# 117               6
# 122               6
# 126              78
# 129              78
# 127               1
# 128               1
# 131              78
# 134              78
# 136              78
# 138              78
# 140             126
# 142             126
# 143              78
# 145              78
# 149             156
# 151             156
# 147               1
# 152               1
# 155              78
# 156              78
# 153               1
# 158               1
# 160              78
# 164              78
# 161               1
# 163               1
# 166             174
# 168             174
# 169             174
# 172             156
# 173             156
