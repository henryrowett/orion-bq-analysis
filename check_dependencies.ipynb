# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import subprocess
import os
import pandas_gbq as pgbq

# %%
import google.auth
from google.auth import compute_engine
from google.cloud import bigquery

# Create the BQ client. This will ask you to log in the first time.

project_id = 'data-engineering-prod'
client = bigquery.Client(project=project_id)

# List all datasets in project
client.list_datasets()

# %%
# list datasets and number of views/tables
datasets = []
for dataset in client.list_datasets():
    views = list(client.list_tables(dataset=dataset.reference))
    datasets.append(views)
    print(dataset.dataset_id + " contains {:d} views".format(len(views)))
    
print("\n" + project_id + " contains {:d} datasets".format(len(datasets)))
# Out:
# landing_andromeda contains 107 views
# landing_andromeda_secure contains 660 views
# landing_identity_secure contains 4 views
# landing_orex_secure contains 16 views
# landing_orion_migration_secure contains 51 views
# landing_orion_secure contains 3 views
# landing_pace_secure contains 1 views
# landing_payments_secure contains 23 views
# product_andromeda_secure contains 195 views
# product_identity_secure contains 1 views
# product_orion contains 31 views
# product_orion_secure contains 99 views
# product_payments_secure contains 1 views
# raw_andromeda_secure contains 418 views
# raw_identity_secure contains 2 views
# raw_orex_secure contains 11 views
# raw_orion_migration_secure contains 13 views
# raw_orion_secure contains 1 views
# raw_pace_secure contains 1 views
# raw_payments_secure contains 5 views
#
# data-engineering-prodcontains 20 datasets

# %%
#From this cell onwards, I am trying to find who (users) are using any of the tables inside the list "topic_list". 
#I am also finding what views use those tables in their logic. 
#This is probably out of the scope at the moment but it will be useful at some point

# %%
print("Collecting data on all views in " + project_id + ". This may take some time...")
views = []

for dataset in client.list_datasets():
    print("Collecting views for: " + dataset.dataset_id)
    
    for view in list(client.list_tables(dataset=dataset.reference)):
        try:
            dataset_ref = bigquery.DatasetReference(project_id, dataset.dataset_id)
            view_ref = dataset_ref.table(view.table_id)
            v = client.get_table(view_ref)
            views.append(v)

        except Exception, err:
            print(err)
            pass
        
print("Done!")
# Out:
# Collecting views for: landing_andromeda
# Collecting views for: landing_andromeda_secure
# Collecting views for: landing_identity_secure
# Collecting views for: landing_orex_secure
# Collecting views for: landing_orion_migration_secure
# Collecting views for: landing_orion_secure
# Collecting views for: landing_pace_secure
# Collecting views for: landing_payments_secure
# Collecting views for: product_andromeda_secure
# Collecting views for: product_identity_secure
# Collecting views for: product_orion
# Collecting views for: product_orion_secure
# Collecting views for: product_payments_secure
# Collecting views for: raw_andromeda_secure
# Collecting views for: raw_identity_secure
# Collecting views for: raw_orex_secure
# Collecting views for: raw_orion_migration_secure
# Collecting views for: raw_orion_secure
# Collecting views for: raw_pace_secure
# Collecting views for: raw_payments_secure
# Done
# [Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_consumption_charge_generated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_consumption_charge_generated_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_consumption_charge_generated_v6')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_consumption_charge_generated_v7')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_consumption_charge_generated_v8')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_contract_created_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_contract_created_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_contract_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_contract_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_electricity_consumption_charge_created_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_electricity_consumption_charge_created_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_gas_consumption_charge_created_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_standing_charge_created_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_standing_charge_created_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_standing_charge_created_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_standing_charge_created_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'energy_contracts_standing_charge_created_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'live_cad_consumption_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'live_cad_pricing_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'losses_consumer_status_update_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'losses_loss_cancelled_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'losses_loss_created_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'losses_loss_objection_cancelled_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'losses_loss_objection_completed_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'losses_loss_objection_created_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_andromeda_import_msd_published_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_blacklisted_meters_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_calorific_value_received_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_consumption_generated_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_consumption_generated_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_consumption_generated_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0010_received_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0010_received_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0010_received_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0010_received_v6')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0010_received_v7')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0010_received_v8')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0010_received_v9')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0019_received_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0019_received_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0086_received_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0086_received_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0086_received_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0149_received_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0149_received_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0150_received_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0150_received_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0150_received_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0188_received_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0188_received_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0188_received_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0217_received_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0303_received_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0303_received_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0303_received_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0311_received_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_d0311_received_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_mri_received_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_mri_received_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_nrl_received_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_flow_trf_received_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gasVolume_generated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gasVolume_generated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gasVolume_generated_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gasVolume_generated_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gas_consumption_generated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gas_consumption_generated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gas_consumption_generated_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gas_consumption_generated_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gas_consumption_generated_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gas_settlement_candidates_dispatched_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gas_settlement_candidates_selected_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_gas_settlement_candidates_unmatched_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_hh_received_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_hh_received_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_industry_estimate_updated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_industry_estimate_updated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_meterReadingCommand_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_meterReading_normalized_errors_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_meterReading_normalized_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_meterReading_settled_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_meterReading_validated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_msd_noEventsNotification_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_msd_received_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_msd_received_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_msd_received_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_msd_received_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_msd_received_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_msd_received_v6')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_msd_simplified_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_msd_stripped_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_orion_estimate_missing_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_orion_estimate_updated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_orion_estimate_updated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_orion_personal_projections_published_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_personal_projections_calculated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_personal_projections_calculated_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_settlement_candidates_dispatched_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_settlement_candidates_selected_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_settlement_candidates_selected_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_settlement_candidates_selected_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_settlement_candidates_unmatched_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_settlement_candidates_unmatched_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'rac_settlement_candidates_unmatched_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'spam_electricitySupplyPoint_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'spam_gasSupplyPoint_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda'), 'spam_gasSupplyPoint_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), '2019_11_rebill_list_patchy_comms')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'big_query_jt')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'collections_extract')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'collections_extract_updates')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'complaints_extract')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'complaints_extract_updates')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_annual_cost_projections_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_annual_cost_projections_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_annual_cost_projections_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_annual_cost_projections_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_annual_cost_projections_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_annual_cost_projections_v6')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_consumption_charge_generated_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_consumption_charge_generated_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_contract_created_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_contract_schedule_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_contract_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_contract_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_contract_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_contract_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_electricity_consumption_charge_created_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_electricity_consumption_charge_created_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_gas_consumption_charge_created_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_price_change_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_standing_charge_created_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_standing_charge_created_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_standing_charge_created_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_standing_charge_created_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_supply_point_tariff_cost_errors')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_supply_point_tariff_costs_testing_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_supply_point_tariff_costs_testing_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_supply_point_tariff_costs_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_supply_point_tariff_costs_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_supply_point_tariff_costs_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_supply_point_tariff_costs_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_supply_point_tariff_costs_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_supply_point_tariff_costs_v6')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_supply_point_tariff_costs_v7')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_tariff_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_tariff_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_tariff_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'energy_contracts_tariff_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_AML_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_AML_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_AQI_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_AQI_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_AQR_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_AQR_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_ASP_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_ASP_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_BOL_XREADOUT01_validated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_BOL_XREADOUT01_validated_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_BOL_XREADOUT01_validated_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_BOL_XREADOUT01_validated_v5')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_BOL_XREADOUT01_validated_v6')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_BOL_XREADOUT01_validated_v7')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_CDR_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_CDR_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_CNF_POST_NEXUS_split_consolidated_v7')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_CNF_POST_NEXUS_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_CNF_POST_NEXUS_split_v6')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_CNF_POST_NEXUS_split_v7')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_CNF_PRE_NEXUS_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_CNF_PRE_NEXUS_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_COI_POST_20171101_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_COI_POST_20171101_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_COI_PRE_20171101_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0001001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0001001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0002001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0002001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0004001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0004001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0010001_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0010002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0010002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0011001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0011001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0012001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0012001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0018001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0018001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0019001_split_consolidated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0019001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0019001_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0030001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0030001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0036001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0040002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0040003_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0041001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0041001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0052001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0052001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0055001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0055001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0057001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0057001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0058001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0058001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0064001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0064001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0065001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0065001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0066001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0066001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0067001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0067001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0068001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0068001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0069001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0069001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0071001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0071001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0081001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0081001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0086001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0086001_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0086001_split_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0086002_split_consolidated_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0086002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0086002_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0086002_split_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0089001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0089002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0089002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0090001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0090001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0091001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0091001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0091002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0091002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0092001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0092001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0093001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0093001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0095001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0095001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0132001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0132001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0139001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0139001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0142001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0142001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0148001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0148001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0149001_split_consolidated_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0149001_split_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0150001_split_consolidated_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0150001_split_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0151001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0151001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0153001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0153001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0155001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0155001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0171001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0171001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0188001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0188001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0203001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0203001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0205001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0205001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0217001_POST_DTC10_7_split_consolidated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0217001_POST_DTC10_7_split_consolidated_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0217001_POST_DTC10_7_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0217001_POST_DTC10_7_split_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0217001_PRE_DTC10_7_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0217001_PRE_DTC10_7_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0217002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0217002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0221001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0221001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0225001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0225002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0225002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0235001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0242001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0242001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0260001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0260001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0260002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0260002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0269004_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0296001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0296001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0300001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0300001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0301001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0301002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0301002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0302001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0302002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0302002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0303001_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0304001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0304001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0306001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0306001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0306002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0306002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0307001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0307002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0307002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0308002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0308002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0309002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0309002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0310001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0310001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0311001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0311001_split_consolidated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0311001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0311001_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0312002_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0312002_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0358001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0358001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0359001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0359001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0360001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0360001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0361001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0361001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0367001_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0367001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_D0380001_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_DCF_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_DCF_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_DRS_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_DRS_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_G0806_split_consolidated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_G0806_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_G0806_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_G0807_split_consolidated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_G0807_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_G0807_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_G0808_split_consolidated_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_G0808_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_LPA_split_consolidated_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_LPA_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MBR_POST_NEXUS_split_consolidated_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MBR_POST_NEXUS_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MBR_POST_NEXUS_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MBR_POST_NEXUS_split_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MBR_PRE_NEXUS_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MBR_PRE_NEXUS_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MBR_PRE_NEXUS_split_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MRI_POST_NEXUS_split_consolidated_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MRI_POST_NEXUS_split_v1')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MRI_POST_NEXUS_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MRI_POST_NEXUS_split_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MRI_POST_NEXUS_split_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MRI_PRE_NEXUS_split_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MRI_PRE_NEXUS_split_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_MRI_PRE_NEXUS_split_v4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'landing_andromeda_secure'), 'flow_NOSI_split_consolidated_v1')),
# ...
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'charge_mandates')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'cheapest_tariff_messaging')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'confirmed_smart_meter_types')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'consumption_blocks')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'consumption_blocks_extract')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'consumption_blocks_old')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'consumption_charges')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'consumption_charges_extract')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'consumption_charges_including_cancelled')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'consumption_loss_adjustments')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'contract_work_items')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'contracted_supply_points')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'contracted_supply_points_old')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'contracts')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'contracts_including_cancelled')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'cos_loss_read_delay_reason_snapshots')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'cos_loss_read_delay_reasons')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'current_gas_settlement_gap_extract')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'dpa_breach_final_bill_exceptions')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'economy_energy_read_history_elec')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'economy_energy_read_history_gas')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'economy_energy_xoserve_portfolio')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'elec_read_dispute_raised')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'elec_read_disputes_raised')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'electricity_coefficients_unrestricted_domestic')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'electricity_msn_non_comm_status')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'end_of_contract_charging_gaps')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'external_reconciliation_loss_notifications')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'final_statement_gsop_exempt_accounts')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'final_statement_prep')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_denylisted')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_denylisted_but_parsed')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_enabled')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_enabled_split')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_last_seen')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_parsed_not_seen_on_gcs')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_parsed_not_seen_on_kafka')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_raw_not_seen_on_gcs')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_reconciliation_status')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_reconciliation_status_aggregate')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_split_consolidated_records_not_seen_on_kafka')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'flows_split_records_not_seen_on_kafka')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'gas_msn_non_comm_status')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'gas_read_disputes_raised')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'gas_settlement_gap_snapshots')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_charge_mandates')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_charge_mandates_detail')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_charge_mandates_snapshots')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_erroneous_charging')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_erroneous_charging_detail')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_erroneous_charging_snapshots')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_expected_consumption_and_charges')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_expected_consumption_and_charges_detail')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_expected_consumption_and_charges_snapshots')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_expected_standing_charges')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_expected_standing_charges_detail')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_expected_standing_charges_snapshots')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_loss_journeys')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_loss_journeys_detail')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'health_check_loss_journeys_snapshots')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'industry_final_reads')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'loss_journeys')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'loss_journeys_detailed')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'loss_journeys_detailed_extract')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'loss_journeys_reads_extract')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'loss_reads_extract')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'loss_smart_reads_extract')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'manual_read_work_items')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'meter_reads')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'migration_metric')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'msd_export_advances')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'msd_export_raw')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_personal_projections_1_latest_mappings')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_1_latest_mappings')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_1_latest_mappings_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_1_latest_mappings_v3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_2_read_intervals')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_2_read_intervals_v2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_3_coefficients')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_4_eacs')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_5_cleaned_intervals')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_6_cleaned_eac')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_7_annualised_advances')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_8_consumption_projections')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'multi_rate_projections_9_structured_consumption_projections')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'non_comms_constraints_0_no_smart_reads_in_six_months')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'non_comms_constraints_1_no_reads_on_or_since_last_gt_bill_date')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'non_comms_constraints_2_different_read_on_gt_billing_date')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'non_comms_constraints_3_have_reads_since_gt_last_bill_date')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'non_comms_constraints_base_data_earliest_after_or_latest_read_before_gt_bill')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'non_comms_constraints_base_data_earliest_read_since_gt_bill')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'non_comms_constraints_base_data_gentrack_latest_bill')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'non_comms_constraints_base_data_latest_read_before_gt_bill')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'non_comms_constraints_base_data_latest_reads')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'non_comms_constraints_overal_eligible')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'open_read_disputes_for_ops')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'orion_loss_confirmation')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'orion_loss_confirmation_extract')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'personal_projections_1_latest_mappings')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'poc_gas_settled_reads_urs')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'poc_gas_volume_msd')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'poc_gentrack_tariff_mapping')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'poc_manual')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'poc_sfe_tariff_config_previous_uploads')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'poc_sfe_tariff_config_reporting')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'poc_sfe_tariff_config_to_upload')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'poc_sfe_tariff_history')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'probate_data')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'prod_support_charges_missing_from_balances')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'prod_support_daily_smash_final_account_reconsiliation')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'prod_support_daily_smash_special_comms')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'prod_support_daily_smash_swo_3')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'prod_support_daily_smash_swo_4')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'prod_support_end_of_contract_charging_gaps_V2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'prod_support_final_statement_cot_to_send_today')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'prod_support_final_statement_exemption_identification')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'prod_support_final_statement_loss_to_send_today')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'prod_support_final_statement_prep_V2')),
#  Table(TableReference(DatasetReference(u'data-engineering-prod', u'product_andromeda_secure'), 'prod_support_final_statement_ready')),
#  ...]

# %%
# Example data from table/view
print("Example table/view and query:")
print("\nView: {}".format(views[0].full_table_id))
print("\nView Query:\n{}".format(views[0].view_query))
print("\nType: {}".format(views[0].table_type))
# Out:
# Example table/view and query:
#
# View: data-engineering-prod:landing_andromeda.energy_contracts_consumption_charge_generated_v2
#
# View Query:
# #standardSQL
# SELECT
#   `kafkaData`,
#   `unionRecord`,
#   `_PARTITIONTIME` `PARTITIONTIME`
# FROM
#   `data-engineering-prod.auto_capture_v2.energy_contracts_consumption_charge_generated_v2`
#
# Type: VIEW

# %%
data = []
for view in views:
    # if the table is created with a query I am assuming it is a view (https://cloud.google.com/bigquery/docs/view-metadata)
    d = [view.dataset_id, view.table_id, view.table_type, view.view_query, view.location, view.self_link]
    data.append(d)
    
df = pd.DataFrame(data).to_json("views.json")
pd.read_json("views.json")
# Out:
#                              0  \
# 0            landing_andromeda
# 1            landing_andromeda
# 10           landing_andromeda
# 100          landing_andromeda
# 1000  product_andromeda_secure
# 1001  product_andromeda_secure
# 1002  product_andromeda_secure
# 1003  product_andromeda_secure
# 1004  product_andromeda_secure
# 1005  product_andromeda_secure
# 1006  product_andromeda_secure
# 1007  product_andromeda_secure
# 1008  product_andromeda_secure
# 1009  product_andromeda_secure
# 101          landing_andromeda
# 1010  product_andromeda_secure
# 1011  product_andromeda_secure
# 1012  product_andromeda_secure
# 1013  product_andromeda_secure
# 1014  product_andromeda_secure
# 1015  product_andromeda_secure
# 1016  product_andromeda_secure
# 1017  product_andromeda_secure
# 1018  product_andromeda_secure
# 1019  product_andromeda_secure
# 102          landing_andromeda
# 1020  product_andromeda_secure
# 1021  product_andromeda_secure
# 1022  product_andromeda_secure
# 1023  product_andromeda_secure
# ...                        ...
# 972   product_andromeda_secure
# 973   product_andromeda_secure
# 974   product_andromeda_secure
# 975   product_andromeda_secure
# 976   product_andromeda_secure
# 977   product_andromeda_secure
# 978   product_andromeda_secure
# 979   product_andromeda_secure
# 98           landing_andromeda
# 980   product_andromeda_secure
# 981   product_andromeda_secure
# 982   product_andromeda_secure
# 983   product_andromeda_secure
# 984   product_andromeda_secure
# 985   product_andromeda_secure
# 986   product_andromeda_secure
# 987   product_andromeda_secure
# 988   product_andromeda_secure
# 989   product_andromeda_secure
# 99           landing_andromeda
# 990   product_andromeda_secure
# 991   product_andromeda_secure
# 992   product_andromeda_secure
# 993   product_andromeda_secure
# 994   product_andromeda_secure
# 995   product_andromeda_secure
# 996   product_andromeda_secure
# 997   product_andromeda_secure
# 998   product_andromeda_secure
# 999   product_andromeda_secure
#
#                                                       1         2  \
# 0      energy_contracts_consumption_charge_generated_v2      VIEW
# 1      energy_contracts_consumption_charge_generated_v3      VIEW
# 10    energy_contracts_electricity_consumption_charg...      VIEW
# 100               rac_settlement_candidates_selected_v3      VIEW
# 1000              prod_support_final_statement_ready_V2     TABLE
# 1001                       prod_support_work_items_prep     TABLE
# 1002                                 rac_d10_simplified      VIEW
# 1003                                 rac_d86_simplified      VIEW
# 1004                rac_elec_replay_service_performance     TABLE
# 1005  rac_electricity_HISTORIC_contractChangeDateEst...      VIEW
# 1006               rac_electricity_billingDateEstimates      VIEW
# 1007        rac_electricity_contractChangeDateEstimates      VIEW
# 1008                       rac_electricity_loadProfiles     TABLE
# 1009       rac_gas_HISTORIC_contractChangeDateEstimates      VIEW
# 101              rac_settlement_candidates_unmatched_v1      VIEW
# 1010                       rac_gas_billingDateEstimates      VIEW
# 1011                rac_gas_contractChangeDateEstimates      VIEW
# 1012                               rac_gas_loadProfiles     TABLE
# 1013                 rac_gas_replay_service_performance     TABLE
# 1014                  rac_internal_billingDateEstimates      VIEW
# 1015           rac_internal_contractChangeDateEstimates      VIEW
# 1016  rac_orion_electricity_personal_projections_mon...      VIEW
# 1017         rac_orion_gas_personal_projections_monthly      VIEW
# 1018             rac_orion_personal_projections_monthly      VIEW
# 1019                     read_dispute_work_item_changes      VIEW
# 102              rac_settlement_candidates_unmatched_v2      VIEW
# 1020                            read_dispute_work_items      VIEW
# 1021                                          registers      VIEW
# 1022                            results_20190524_164200     TABLE
# 1023                            settled_gas_reads_orion     TABLE
# ...                                                 ...       ...
# 972   non_comms_constraints_base_data_gentrack_lates...      VIEW
# 973   non_comms_constraints_base_data_latest_read_be...      VIEW
# 974        non_comms_constraints_base_data_latest_reads      VIEW
# 975               non_comms_constraints_overal_eligible      VIEW
# 976                          open_read_disputes_for_ops      VIEW
# 977                             orion_loss_confirmation      VIEW
# 978                     orion_loss_confirmation_extract     TABLE
# 979              personal_projections_1_latest_mappings      VIEW
# 98                rac_settlement_candidates_selected_v1      VIEW
# 980                           poc_gas_settled_reads_urs      VIEW
# 981                                  poc_gas_volume_msd      VIEW
# 982                         poc_gentrack_tariff_mapping     TABLE
# 983                                          poc_manual     TABLE
# 984              poc_sfe_tariff_config_previous_uploads     TABLE
# 985                     poc_sfe_tariff_config_reporting      VIEW
# 986                     poc_sfe_tariff_config_to_upload      VIEW
# 987                              poc_sfe_tariff_history     TABLE
# 988                                        probate_data  EXTERNAL
# 989          prod_support_charges_missing_from_balances     TABLE
# 99                rac_settlement_candidates_selected_v2      VIEW
# 990   prod_support_daily_smash_final_account_reconsi...     TABLE
# 991              prod_support_daily_smash_special_comms     TABLE
# 992                      prod_support_daily_smash_swo_3     TABLE
# 993                      prod_support_daily_smash_swo_4     TABLE
# 994       prod_support_end_of_contract_charging_gaps_V2     TABLE
# 995      prod_support_final_statement_cot_to_send_today     TABLE
# 996   prod_support_final_statement_exemption_identif...     TABLE
# 997     prod_support_final_statement_loss_to_send_today     TABLE
# 998                prod_support_final_statement_prep_V2     TABLE
# 999                  prod_support_final_statement_ready     TABLE
#
#                                                       3   4  \
# 0     #standardSQL\nSELECT\n  `kafkaData`,\n  `union...  EU
# 1     #standardSQL\nSELECT\n  `kafkaData`,\n  `union...  EU
# 10    #standardSQL\nSELECT\n  `metadata`,\n  `supply...  EU
# 100   #standardSQL\nSELECT\n  `metadata`,\n  `msn`,\...  EU
# 1000                                               None  EU
# 1001                                               None  EU
# 1002  SELECT \n   header.fileIdentifier\n  ,header.f...  EU
# 1003  SELECT\n   header.fileIdentifier\n  ,header.fr...  EU
# 1004                                               None  EU
# 1005  SELECT MSN AS msn\n      , 'EstimatedReading' ...  EU
# 1006  SELECT MSN AS msn\n      , 'EstimatedReading' ...  EU
# 1007  SELECT MSN AS msn\n      , 'EstimatedReading' ...  EU
# 1008                                               None  EU
# 1009  SELECT MSN AS msn\n      , 'EstimatedReading' ...  EU
# 101   #standardSQL\nSELECT\n  `metadata`,\n  `error`...  EU
# 1010  SELECT MSN AS msn\n      , 'EstimatedReading' ...  EU
# 1011  SELECT MSN AS msn\n      , 'EstimatedReading' ...  EU
# 1012                                               None  EU
# 1013                                               None  EU
# 1014  --CONTRACTS\n--###############################...  EU
# 1015  WITH cte_contracts_raw AS(  \n  SELECT\n    a....  EU
# 1016   WITH\n  v3 AS (\n      SELECT \n         even...  EU
# 1017  WITH\n  v3 AS (\n    SELECT \n       event.Gas...  EU
# 1018  WITH\n  v3 AS (\n    SELECT \n       event.Gas...  EU
# 1019  with cte_sequence as\n(\n  select wi.workItemI...  EU
# 102   #standardSQL\nSELECT\n  `metadata`,\n  `error`...  EU
# 1020  with cte_dedupe as\n(\n  select wi.workItemId,...  EU
# 1021  select mpxn,\n       0 as tier,\n       '00001...  EU
# 1022                                               None  EU
# 1023                                               None  EU
# ...                                                 ...  ..
# 972     -- latest Gentrack bill and read\nWITH gas A...  EU
# 973     SELECT \n     er.msn\n    ,accountNumber\n  ...  EU
# 974   WITH e_read AS (\n  -- elec recent reads\n  SE...  EU
# 975   \nSELECT\n      A.Account_No AS accountNumber\...  EU
# 976   SELECT\n  accountNumber as Account_No,\n  mpxn...  EU
# 977   # Loss confirmed supplies logic.\n# \n# Author...  EU
# 978                                                None  EU
# 979   WITH mappings AS (\n  SELECT\n     MPXN\n    ,...  EU
# 98    #standardSQL\nSELECT\n  `metadata`,\n  `msn`,\...  EU
# 980   select\n  *,\n  'URS' as source\nfrom\n  (\n  ...  EU
# 981   SELECT\n  event.GasVolumeConsumptionGeneratedE...  EU
# 982                                                None  EU
# 983                                                None  EU
# 984                                                None  EU
# 985   select\n  uploaded.servicePointNo as mpxn,\n  ...  EU
# 986   -- Looks back 7 days on startDate and createdD...  EU
# 987                                                None  EU
# 988                                                None  EU
# 989                                                None  EU
# 99    #standardSQL\nSELECT\n  `metadata`,\n  `msn`,\...  EU
# 990                                                None  EU
# 991                                                None  EU
# 992                                                None  EU
# 993                                                None  EU
# 994                                                None  EU
# 995                                                None  EU
# 996                                                None  EU
# 997                                                None  EU
# 998                                                None  EU
# 999                                                None  EU
#
#                                                       5
# 0     https://bigquery.googleapis.com/bigquery/v2/pr...
# 1     https://bigquery.googleapis.com/bigquery/v2/pr...
# 10    https://bigquery.googleapis.com/bigquery/v2/pr...
# 100   https://bigquery.googleapis.com/bigquery/v2/pr...
# 1000  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1001  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1002  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1003  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1004  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1005  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1006  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1007  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1008  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1009  https://bigquery.googleapis.com/bigquery/v2/pr...
# 101   https://bigquery.googleapis.com/bigquery/v2/pr...
# 1010  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1011  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1012  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1013  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1014  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1015  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1016  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1017  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1018  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1019  https://bigquery.googleapis.com/bigquery/v2/pr...
# 102   https://bigquery.googleapis.com/bigquery/v2/pr...
# 1020  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1021  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1022  https://bigquery.googleapis.com/bigquery/v2/pr...
# 1023  https://bigquery.googleapis.com/bigquery/v2/pr...
# ...                                                 ...
# 972   https://bigquery.googleapis.com/bigquery/v2/pr...
# 973   https://bigquery.googleapis.com/bigquery/v2/pr...
# 974   https://bigquery.googleapis.com/bigquery/v2/pr...
# 975   https://bigquery.googleapis.com/bigquery/v2/pr...
# 976   https://bigquery.googleapis.com/bigquery/v2/pr...
# 977   https://bigquery.googleapis.com/bigquery/v2/pr...
# 978   https://bigquery.googleapis.com/bigquery/v2/pr...
# 979   https://bigquery.googleapis.com/bigquery/v2/pr...
# 98    https://bigquery.googleapis.com/bigquery/v2/pr...
# 980   https://bigquery.googleapis.com/bigquery/v2/pr...
# 981   https://bigquery.googleapis.com/bigquery/v2/pr...
# 982   https://bigquery.googleapis.com/bigquery/v2/pr...
# 983   https://bigquery.googleapis.com/bigquery/v2/pr...
# 984   https://bigquery.googleapis.com/bigquery/v2/pr...
# 985   https://bigquery.googleapis.com/bigquery/v2/pr...
# 986   https://bigquery.googleapis.com/bigquery/v2/pr...
# 987   https://bigquery.googleapis.com/bigquery/v2/pr...
# 988   https://bigquery.googleapis.com/bigquery/v2/pr...
# 989   https://bigquery.googleapis.com/bigquery/v2/pr...
# 99    https://bigquery.googleapis.com/bigquery/v2/pr...
# 990   https://bigquery.googleapis.com/bigquery/v2/pr...
# 991   https://bigquery.googleapis.com/bigquery/v2/pr...
# 992   https://bigquery.googleapis.com/bigquery/v2/pr...
# 993   https://bigquery.googleapis.com/bigquery/v2/pr...
# 994   https://bigquery.googleapis.com/bigquery/v2/pr...
# 995   https://bigquery.googleapis.com/bigquery/v2/pr...
# 996   https://bigquery.googleapis.com/bigquery/v2/pr...
# 997   https://bigquery.googleapis.com/bigquery/v2/pr...
# 998   https://bigquery.googleapis.com/bigquery/v2/pr...
# 999   https://bigquery.googleapis.com/bigquery/v2/pr...
#
# [1643 rows x 6 columns]
